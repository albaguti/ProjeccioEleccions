# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
#Colors grafics
junts = [0,202/255,180/255]
psc = [236/255,0,26/255]
erc = [237/255,172/255,43/255]
comuns = [199/255,21/255,104/255]
pp = [0,151/255,229/255]
vox = [80/255,176/255,40/255]
cup = [232/255,202/255,33/255]
ciudadanos = [246/255,95/255,8/255]
partits = ["ERC","Junts","PSC","PP","Comuns","CUP","VOX"]
color1 = [erc,junts,psc,pp,comuns,cup,vox]
partits2019 = ["ERC","Junts","PSC","PP","Comuns","CUP","VOX","Cs"]
color2 = [erc,junts,psc,pp,comuns,cup,vox,ciudadanos]

# %% [markdown]
# <h3> Functions

# %%
# Funció que permet calcular el repartiment d'escons en funció dels resultats electorals,
# els escons a repartir i els partits que es reparteixen els escons (els que tenen > 3% 
# del vot vàlid)

def repartimentEscons(resultats,escons,vots):    
    res = []
    tmp = []
    tmp2=[]
    esc =  []
    for i in range(1,escons+1):
        for j in range(len(resultats)):
             tmp.append(round((resultats[j]/i)))
             tmp2.append(round((resultats[j]/i)))
        res.append(tmp)
        tmp = []
    tmp2 = sorted(tmp2,reverse=True)
    limit = tmp2[escons-1]
    for i in range(len(res)):
        for j in range(len(res[0])):
            if res[i][j] >= limit:
                esc.append(vots[j])
                
    return (res,limit,esc)

# %%
# Funció que permet calcular el repartiment d'escons en funció de l'abstenció dels 
# partits independentistes

def incrementAbstencio(res,generals,provincia,abstencio):
    barcelona = [0,2,4]
    girona = [0,1,3]
    lleida = [0,1,4]
    tarragona = [0,1,6]
    vots_indi = 0
    resultats = res.copy()
    if provincia == "Lleida":
        for i in lleida:
            resultats[i] -= resultats[i] * abstencio
            vots_indi += resultats[i]
            if (resultats[i]/generals.Lleida.loc[0]) < 0.03 :
                resultats[i] = 0
                
        print(f"Augment abstenció quan els indepes perden el {abstencio*100}% dels vots:", 
      round(100*(generals.Lleida.loc[4]-vots_indi)/(generals.Lleida.loc[0]+generals.Lleida.loc[1]),2),"%")
        
    if provincia == "Barcelona":
        for i in barcelona:
            resultats[i] -= resultats[i] * abstencio
            vots_indi += resultats[i]
            if (resultats[i]/generals.Barcelona.loc[0]) < 0.03 :
                resultats[i] = 0
        print(f"Augment abstenció quan els indepes perden el {abstencio*100}% dels vots:", 
      round(100*(generals.Barcelona.loc[4]-vots_indi)/(generals.Barcelona.loc[0]+generals.Barcelona.loc[1]),2),"%")
            
    if provincia == "Girona":
        for i in girona:
            resultats[i] -= resultats[i] * abstencio
            vots_indi += resultats[i]
            if (resultats[i]/generals.Girona.loc[0]) < 0.03 :
                resultats[i] = 0
        print(f"Augment abstenció quan els indepes perden el {abstencio*100}% dels vots:", 
      round(100*(generals.Girona.loc[4]-vots_indi)/(generals.Girona.loc[0]+generals.Girona.loc[1]),2),"%")

    if provincia == "Tarragona":
        for i in tarragona:
            resultats[i] -= resultats[i] * abstencio
            vots_indi += resultats[i]
            if (resultats[i]/generals.Tarragona.loc[0]) < 0.03 :
                resultats[i] = 0
        print(f"Augment abstenció quan els indepes perden el {abstencio*100}% dels vots:", 
     round(100*(generals.Tarragona.loc[4]-vots_indi)/(generals.Tarragona.loc[0]+generals.Tarragona.loc[1]),2),"%")
    return resultats

# %% [markdown]
# <h1> Projecció resultats eleccions

# %% [markdown]
# <h2> Càlcul per provincies

# %% [markdown]
# <ul><li>Barcelona: 32</li>
#     <li>Girona:  6</li>
#     <li>Lleida: 4</li>
#     <li>Tarragon 6</li>
# </ul>
# Total 48 escons a repartir

# %% [markdown]
# <h3> Carreguem les dades electorals de les eleccions municipals de Maig de 2023

# %%
dades_eleccions = pd.read_csv("data/resultats_generals.csv")
dades_eleccions
# Out:
#             Vots  Barcelona  Percentatge Barcelona    Girona  \
# 0    Vots totals  2251163.0                   0.55  290300.0
# 1    Abstencions  1818557.0                   0.45  244718.0
# 2  Vots en blanc    34085.0                   0.02    6306.0
# 3      Vots nuls    28282.0                   0.01    5851.0
# 4     Vot indepe   782633.0                   0.35  168382.0
#
#    Percentatge vot Girona  Lleida  Percentatge de vot Lleida  Tarragona  \
# 0                0.542500  180233                       0.59   329004.0
# 1                0.457400  122911                       0.41   254438.0
# 2                0.022100    4922                       0.03     6100.0
# 3                0.020100    4259                       0.02     6490.0
# 4                0.580028   96253                       0.53   152369.0
#
#    Percentatge de vot Tarragona  Total Catalunya  Percentatge
# 0                          0.56          3050700         0.56
# 1                          0.44          2440624         0.44
# 2                          0.02            51413         0.02
# 3                          0.02            44882         0.01
# 4                          0.46          1199637         0.39

# %% [markdown]
# <h2> Resultats electorals municipals per provincies

# %% [markdown]
# <h3> Barcelona

# %%
dades_barcelona = pd.read_csv("data/ResultatsBarcelona.csv")
dades_barcelona
# Out:
#           Vots  Barcelona  Percentatge Barcelona
# 0          ERC     332314                 0.1494
# 1          PSC     571901                 0.2572
# 2        Junts     356644                 0.1604
# 3       Comuns     243065                 0.1093
# 4          CUP      93675                 0.0421
# 5           PP     211593                 0.0951
# 6          VOX     120213                 0.0540
# 7       ARA PL      27384                 0.0123
# 8    AAE1OSONA       3724                 0.0016
# 9          TXT      26732                 0.0120
# 10   AM-LVDVDM       2577                 0.0011
# 11  POBLE UNIT        216                 0.0009
# 12        MXGI       1862                 0.0008
# 13         FIC       1448                 0.0006

# %% [markdown]
# <h4> Si aquests mateixos resultats s'obtinguessin a les Generals de Juliol 2023, el repartiment d'escons a Barcelona seria:

# %%
esconsBarcelona = 32
resultats_Barcelona = dades_barcelona["Barcelona"].copy()
partits_Barcelona = dades_barcelona["Vots"].copy()

# %%
res,limit,esconsRepartitsBarcelona = repartimentEscons(resultats_Barcelona,esconsBarcelona,partits_Barcelona)
dataBarcelona = pd.DataFrame(res, columns=dades_barcelona["Vots"])
dataBarcelona.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# <style type="text/css">
# #T_15f8c_row0_col0, #T_15f8c_row0_col1, #T_15f8c_row0_col2, #T_15f8c_row0_col3, #T_15f8c_row0_col4, #T_15f8c_row0_col5, #T_15f8c_row0_col6, #T_15f8c_row1_col0, #T_15f8c_row1_col1, #T_15f8c_row1_col2, #T_15f8c_row1_col3, #T_15f8c_row1_col5, #T_15f8c_row1_col6, #T_15f8c_row2_col0, #T_15f8c_row2_col1, #T_15f8c_row2_col2, #T_15f8c_row2_col3, #T_15f8c_row2_col5, #T_15f8c_row3_col0, #T_15f8c_row3_col1, #T_15f8c_row3_col2, #T_15f8c_row3_col3, #T_15f8c_row4_col0, #T_15f8c_row4_col1, #T_15f8c_row4_col2, #T_15f8c_row5_col0, #T_15f8c_row5_col1, #T_15f8c_row5_col2, #T_15f8c_row6_col1, #T_15f8c_row7_col1, #T_15f8c_row8_col1, #T_15f8c_row9_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_15f8c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_15f8c_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_15f8c_level0_col1" class="col_heading level0 col1" >PSC</th>
#       <th id="T_15f8c_level0_col2" class="col_heading level0 col2" >Junts</th>
#       <th id="T_15f8c_level0_col3" class="col_heading level0 col3" >Comuns</th>
#       <th id="T_15f8c_level0_col4" class="col_heading level0 col4" >CUP</th>
#       <th id="T_15f8c_level0_col5" class="col_heading level0 col5" >PP</th>
#       <th id="T_15f8c_level0_col6" class="col_heading level0 col6" >VOX</th>
#       <th id="T_15f8c_level0_col7" class="col_heading level0 col7" >ARA PL</th>
#       <th id="T_15f8c_level0_col8" class="col_heading level0 col8" >AAE1OSONA</th>
#       <th id="T_15f8c_level0_col9" class="col_heading level0 col9" >TXT</th>
#       <th id="T_15f8c_level0_col10" class="col_heading level0 col10" >AM-LVDVDM</th>
#       <th id="T_15f8c_level0_col11" class="col_heading level0 col11" >POBLE UNIT</th>
#       <th id="T_15f8c_level0_col12" class="col_heading level0 col12" >MXGI</th>
#       <th id="T_15f8c_level0_col13" class="col_heading level0 col13" >FIC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15f8c_row0_col0" class="data row0 col0" >332314</td>
#       <td id="T_15f8c_row0_col1" class="data row0 col1" >571901</td>
#       <td id="T_15f8c_row0_col2" class="data row0 col2" >356644</td>
#       <td id="T_15f8c_row0_col3" class="data row0 col3" >243065</td>
#       <td id="T_15f8c_row0_col4" class="data row0 col4" >93675</td>
#       <td id="T_15f8c_row0_col5" class="data row0 col5" >211593</td>
#       <td id="T_15f8c_row0_col6" class="data row0 col6" >120213</td>
#       <td id="T_15f8c_row0_col7" class="data row0 col7" >27384</td>
#       <td id="T_15f8c_row0_col8" class="data row0 col8" >3724</td>
#       <td id="T_15f8c_row0_col9" class="data row0 col9" >26732</td>
#       <td id="T_15f8c_row0_col10" class="data row0 col10" >2577</td>
#       <td id="T_15f8c_row0_col11" class="data row0 col11" >216</td>
#       <td id="T_15f8c_row0_col12" class="data row0 col12" >1862</td>
#       <td id="T_15f8c_row0_col13" class="data row0 col13" >1448</td>
#     </tr>
#     <tr>
#       <th id="T_15f8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15f8c_row4_col0" class="data row4 col0" >66463</td>
#       <td id="T_15f8c_row4_col1" class="data row4 col1" >114380</td>
#       <td id="T_15f8c_row4_col2" class="data row4 col2" >71329</td>
#       <td id="T_15f8c_row4_col3" class="data row4 col3" >48613</td>
#       <td id="T_15f8c_row4_col4" class="data row4 col4" >18735</td>
#       <td id="T_15f8c_row4_col5" class="data row4 col5" >42319</td>
#       <td id="T_15f8c_row4_col6" class="data row4 col6" >24043</td>
#       <td id="T_15f8c_row4_col7" class="data row4 col7" >5477</td>
#       <td id="T_15f8c_row4_col8" class="data row4 col8" >745</td>
#       <td id="T_15f8c_row4_col9" class="data row4 col9" >5346</td>
#       <td id="T_15f8c_row4_col10" class="data row4 col10" >515</td>
#       <td id="T_15f8c_row4_col11" class="data row4 col11" >43</td>
#       <td id="T_15f8c_row4_col12" class="data row4 col12" >372</td>
#       <td id="T_15f8c_row4_col13" class="data row4 col13" >290</td>
#     </tr>
#     <tr>
#       <th id="T_15f8c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_15f8c_row5_col0" class="data row5 col0" >55386</td>
#       <td id="T_15f8c_row5_col1" class="data row5 col1" >95317</td>
#       <td id="T_15f8c_row5_col2" class="data row5 col2" >59441</td>
#       <td id="T_15f8c_row5_col3" class="data row5 col3" >40511</td>
#       <td id="T_15f8c_row5_col4" class="data row5 col4" >15612</td>
#       <td id="T_15f8c_row5_col5" class="data row5 col5" >35266</td>
#       <td id="T_15f8c_row5_col6" class="data row5 col6" >20036</td>
#       <td id="T_15f8c_row5_col7" class="data row5 col7" >4564</td>
#       <td id="T_15f8c_row5_col8" class="data row5 col8" >621</td>
#       <td id="T_15f8c_row5_col9" class="data row5 col9" >4455</td>
#       <td id="T_15f8c_row5_col10" class="data row5 col10" >430</td>

# %%
dict_resultatsBarcelona = {}
for i in partits:
    dict_resultatsBarcelona[i] = esconsRepartitsBarcelona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsBarcelona.keys()),list(dict_resultatsBarcelona.values()), color=color1);

# %% [markdown]
# <h3>Girona

# %%
dades_girona = pd.read_csv("data/ResultatsGirona.csv")
dades_girona
# Out:
#          Vots  Girona  Percentatge vot Girona
# 0       Junts   80488                  0.2829
# 1         ERC   64658                  0.2273
# 2         PSC   40045                  0.1407
# 3         CUP   23236                  0.0816
# 4          TE   12787                  0.0449
# 5     IDSELVA    8071                  0.0283
# 6         IDC    2221                  0.0078
# 7         VOX    8608                  0.0302
# 8      Comuns    7223                  0.0253
# 9      ARA PL    6546                  0.0230
# 10         PP    7186                  0.0252
# 11  SOMMESCAT    1624                  0.0057

# %%
esconsGirona = 6
resultats_Girona = dades_girona["Girona"].copy()
partits_Girona = dades_girona["Vots"].copy()

# %%
res,limit,esconsRepartitsGirona = repartimentEscons(resultats_Girona,esconsGirona,partits_Girona)
dataGirona = pd.DataFrame(res, columns=dades_girona["Vots"])

# %%
dict_resultatsGirona = {}
for i in partits:
    dict_resultatsGirona[i] = esconsRepartitsGirona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsGirona.keys()),list(dict_resultatsGirona.values()), color=color1);

# %% [markdown]
# <h3>Lleida

# %%
dades_lleida = pd.read_csv("data/ResultatsLleida.csv")
dades_lleida
# Out:
#                                      Vots  Lleida  Percentatge de vot Lleida
# 0                                     ERC   48099                     0.2733
# 1                                   Junts   47522                     0.2700
# 2                                     PSC   30950                     0.1758
# 3                                  ARA PL    8457                     0.0480
# 4                                     CUP     632                     0.0359
# 5                                      PP   10444                     0.0593
# 6                                 CDA-PNA     145                     0.0082
# 7                       AAE1PALLARSSOBIRA     321                     0.0018
# 8                                      EV     363                     0.0020
# 9   AGRUPACIÓ D'ELECTORS-PRIMER ALCOLETGE     847                     0.0048
# 10                                    APC     783                     0.0044

# %%
esconsLleida = 4
resultats_Lleida = dades_lleida["Lleida"].copy()
partits_Lleida = dades_lleida["Vots"].copy()

# %%
res,limit,esconsRepartitsLleida = repartimentEscons(resultats_Lleida,esconsLleida,partits_Lleida)
dataLleida = pd.DataFrame(res, columns=dades_lleida["Vots"])
dataLleida.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# <style type="text/css">
# #T_63f8b_row0_col0, #T_63f8b_row0_col1, #T_63f8b_row0_col2, #T_63f8b_row1_col0 {
#   background-color: green;
# }
# </style>
# <table id="T_63f8b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_63f8b_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_63f8b_level0_col1" class="col_heading level0 col1" >Junts</th>
#       <th id="T_63f8b_level0_col2" class="col_heading level0 col2" >PSC</th>
#       <th id="T_63f8b_level0_col3" class="col_heading level0 col3" >ARA PL</th>
#       <th id="T_63f8b_level0_col4" class="col_heading level0 col4" >CUP</th>
#       <th id="T_63f8b_level0_col5" class="col_heading level0 col5" >PP</th>
#       <th id="T_63f8b_level0_col6" class="col_heading level0 col6" >CDA-PNA</th>
#       <th id="T_63f8b_level0_col7" class="col_heading level0 col7" >AAE1PALLARSSOBIRA</th>
#       <th id="T_63f8b_level0_col8" class="col_heading level0 col8" >EV</th>
#       <th id="T_63f8b_level0_col9" class="col_heading level0 col9" >AGRUPACIÓ D'ELECTORS-PRIMER ALCOLETGE</th>
#       <th id="T_63f8b_level0_col10" class="col_heading level0 col10" >APC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63f8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63f8b_row0_col0" class="data row0 col0" >48099</td>
#       <td id="T_63f8b_row0_col1" class="data row0 col1" >47522</td>
#       <td id="T_63f8b_row0_col2" class="data row0 col2" >30950</td>
#       <td id="T_63f8b_row0_col3" class="data row0 col3" >8457</td>
#       <td id="T_63f8b_row0_col4" class="data row0 col4" >632</td>
#       <td id="T_63f8b_row0_col5" class="data row0 col5" >10444</td>
#       <td id="T_63f8b_row0_col6" class="data row0 col6" >145</td>
#       <td id="T_63f8b_row0_col7" class="data row0 col7" >321</td>
#       <td id="T_63f8b_row0_col8" class="data row0 col8" >363</td>
#       <td id="T_63f8b_row0_col9" class="data row0 col9" >847</td>
#       <td id="T_63f8b_row0_col10" class="data row0 col10" >783</td>
#     </tr>
#     <tr>
#       <th id="T_63f8b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
# 9  APCANVI       1638                        0.0050

# %%
esconsTarragona = 6
resultats_Tarragona = dades_tarragona["Tarragona"].copy()
partits_Tarragona = dades_tarragona["Vots"].copy()

# %%
res,limit,esconsRepartitsTarragona = repartimentEscons(resultats_Tarragona,esconsTarragona,partits_Tarragona)
dataTarragona = pd.DataFrame(res, columns=dades_tarragona["Vots"])
dataTarragona.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# <style type="text/css">
# #T_a2e9c_row0_col0, #T_a2e9c_row0_col1, #T_a2e9c_row0_col2, #T_a2e9c_row1_col0, #T_a2e9c_row1_col1, #T_a2e9c_row1_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_a2e9c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_a2e9c_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_a2e9c_level0_col1" class="col_heading level0 col1" >Junts</th>
#       <th id="T_a2e9c_level0_col2" class="col_heading level0 col2" >PSC</th>
#       <th id="T_a2e9c_level0_col3" class="col_heading level0 col3" >ARA PL</th>
#       <th id="T_a2e9c_level0_col4" class="col_heading level0 col4" >F.I.C.</th>
#       <th id="T_a2e9c_level0_col5" class="col_heading level0 col5" >Comuns</th>
#       <th id="T_a2e9c_level0_col6" class="col_heading level0 col6" >CUP</th>
#       <th id="T_a2e9c_level0_col7" class="col_heading level0 col7" >PP</th>
#       <th id="T_a2e9c_level0_col8" class="col_heading level0 col8" >VOX</th>
#       <th id="T_a2e9c_level0_col9" class="col_heading level0 col9" >APCANVI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2e9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2e9c_row0_col0" class="data row0 col0" >74762</td>
#       <td id="T_a2e9c_row0_col1" class="data row0 col1" >67435</td>
#       <td id="T_a2e9c_row0_col2" class="data row0 col2" >70053</td>
#       <td id="T_a2e9c_row0_col3" class="data row0 col3" >13057</td>
#       <td id="T_a2e9c_row0_col4" class="data row0 col4" >3953</td>
#       <td id="T_a2e9c_row0_col5" class="data row0 col5" >12465</td>
#       <td id="T_a2e9c_row0_col6" class="data row0 col6" >10172</td>
#       <td id="T_a2e9c_row0_col7" class="data row0 col7" >17890</td>
#       <td id="T_a2e9c_row0_col8" class="data row0 col8" >16793</td>
#       <td id="T_a2e9c_row0_col9" class="data row0 col9" >1638</td>
#     </tr>
#     <tr>
#       <th id="T_a2e9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2e9c_row1_col0" class="data row1 col0" >37381</td>
#       <td id="T_a2e9c_row1_col1" class="data row1 col1" >33718</td>
#       <td id="T_a2e9c_row1_col2" class="data row1 col2" >35026</td>
#       <td id="T_a2e9c_row1_col3" class="data row1 col3" >6528</td>
#       <td id="T_a2e9c_row1_col4" class="data row1 col4" >1976</td>
#       <td id="T_a2e9c_row1_col5" class="data row1 col5" >6232</td>
#       <td id="T_a2e9c_row1_col6" class="data row1 col6" >5086</td>
#       <td id="T_a2e9c_row1_col7" class="data row1 col7" >8945</td>
#       <td id="T_a2e9c_row1_col8" class="data row1 col8" >8396</td>
#       <td id="T_a2e9c_row1_col9" class="data row1 col9" >819</td>
#     </tr>
#     <tr>
#       <th id="T_a2e9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2e9c_row2_col0" class="data row2 col0" >24921</td>
#       <td id="T_a2e9c_row2_col1" class="data row2 col1" >22478</td>
#       <td id="T_a2e9c_row2_col2" class="data row2 col2" >23351</td>
#       <td id="T_a2e9c_row2_col3" class="data row2 col3" >4352</td>
#       <td id="T_a2e9c_row2_col4" class="data row2 col4" >1318</td>
#       <td id="T_a2e9c_row2_col5" class="data row2 col5" >4155</td>
#       <td id="T_a2e9c_row2_col6" class="data row2 col6" >3391</td>
#       <td id="T_a2e9c_row2_col7" class="data row2 col7" >5963</td>
#       <td id="T_a2e9c_row2_col8" class="data row2 col8" >5598</td>
#       <td id="T_a2e9c_row2_col9" class="data row2 col9" >546</td>
#     </tr>
#     <tr>
#       <th id="T_a2e9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a2e9c_row3_col0" class="data row3 col0" >18690</td>
#       <td id="T_a2e9c_row3_col1" class="data row3 col1" >16859</td>
#       <td id="T_a2e9c_row3_col2" class="data row3 col2" >17513</td>
#       <td id="T_a2e9c_row3_col3" class="data row3 col3" >3264</td>
#       <td id="T_a2e9c_row3_col4" class="data row3 col4" >988</td>
#       <td id="T_a2e9c_row3_col5" class="data row3 col5" >3116</td>
#       <td id="T_a2e9c_row3_col6" class="data row3 col6" >2543</td>
#       <td id="T_a2e9c_row3_col7" class="data row3 col7" >4472</td>
#       <td id="T_a2e9c_row3_col8" class="data row3 col8" >4198</td>
#       <td id="T_a2e9c_row3_col9" class="data row3 col9" >410</td>
#     </tr>
#     <tr>
#       <th id="T_a2e9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a2e9c_row4_col0" class="data row4 col0" >14952</td>
#       <td id="T_a2e9c_row4_col1" class="data row4 col1" >13487</td>
#       <td id="T_a2e9c_row4_col2" class="data row4 col2" >14011</td>
#       <td id="T_a2e9c_row4_col3" class="data row4 col3" >2611</td>
#       <td id="T_a2e9c_row4_col4" class="data row4 col4" >791</td>
#       <td id="T_a2e9c_row4_col5" class="data row4 col5" >2493</td>
#       <td id="T_a2e9c_row4_col6" class="data row4 col6" >2034</td>
#       <td id="T_a2e9c_row4_col7" class="data row4 col7" >3578</td>
#       <td id="T_a2e9c_row4_col8" class="data row4 col8" >3359</td>
#       <td id="T_a2e9c_row4_col9" class="data row4 col9" >328</td>
#     </tr>
#     <tr>
#       <th id="T_a2e9c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a2e9c_row5_col0" class="data row5 col0" >12460</td>
#       <td id="T_a2e9c_row5_col1" class="data row5 col1" >11239</td>
#       <td id="T_a2e9c_row5_col2" class="data row5 col2" >11676</td>
#       <td id="T_a2e9c_row5_col3" class="data row5 col3" >2176</td>
#       <td id="T_a2e9c_row5_col4" class="data row5 col4" >659</td>
#       <td id="T_a2e9c_row5_col5" class="data row5 col5" >2078</td>
#       <td id="T_a2e9c_row5_col6" class="data row5 col6" >1695</td>
#       <td id="T_a2e9c_row5_col7" class="data row5 col7" >2982</td>
#       <td id="T_a2e9c_row5_col8" class="data row5 col8" >2799</td>
#       <td id="T_a2e9c_row5_col9" class="data row5 col9" >273</td>
#     </tr>
#   </tbody>
# </table>

# %%
dict_resultatsTarragona = {}
for i in partits:
    dict_resultatsTarragona[i] = esconsRepartitsTarragona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsTarragona.keys()),list(dict_resultatsTarragona.values()), color=color1);

# %%
fig, axs = plt.subplots(2, 2,figsize=(9, 8))
fig.suptitle("Projecció resultats municipals a les espanyoles")
axs[0,0].set_title("Barcelona");
axs[0,1].set_title("Girona");
axs[1,0].set_title("Lleida");
axs[1,1].set_title("Tarragona");
axs[0,0].bar(list(dict_resultatsBarcelona.keys()),list(dict_resultatsBarcelona.values()), color=color1);
axs[0,1].bar(list(dict_resultatsGirona.keys()),list(dict_resultatsGirona.values()), color=color1);
axs[1,0].bar(list(dict_resultatsLleida.keys()),list(dict_resultatsLleida.values()), color=color1);
axs[1,1].bar(list(dict_resultatsTarragona.keys()),list(dict_resultatsTarragona.values()), color=color1);

# %% [markdown]
# <h4> Resultats globals

# %%
esconsCatalunya = esconsRepartitsBarcelona + esconsRepartitsGirona + esconsRepartitsLleida + esconsRepartitsTarragona

dict_resultats = {}
for i in partits:
    dict_resultats[i] = esconsCatalunya.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultats.keys()),list(dict_resultats.values()), color=color1);

# %%
dict_resultats = {}
for i in partits:
    dict_resultats[i] = esconsCatalunya.count(i)
  
plt.pie(list(dict_resultats.values()), labels = list(dict_resultats.keys()),colors=color2);

# %% [markdown]
# <h3>Resultats 2019

# %%
erc = ["ERC" for i in range(13)]
psc = ["PSC" for i in range(12)]
junts = ["Junts" for i in range(8)]
comuns = ["Comuns" for i in range(7)]
pp = ["PP" for i in range(2)]
cup = ["CUP" for i in range(2)]
vox = ["VOX" for i in range(2)]
ciudadanos = ["Cs" for i in range(2)]
esconsCatalunya2019 = erc + psc + junts + comuns + pp + cup + vox + ciudadanos

# %%
dict_resultats2019 = {}
for i in partits2019:
    dict_resultats2019[i] = esconsCatalunya2019.count(i)

# %%
plt.bar(list(dict_resultats2019.keys()),list(dict_resultats2019.values()), color=color2);

# %%
plt.pie(list(dict_resultats2019.values()), labels = list(dict_resultats2019.keys()), colors=color2);

# %% [markdown]
# <h4> Comparativa vs 2019

# %%
fig, axs = plt.subplots(1,2,figsize=(8, 4))
#fig.suptitle("Projecció resultats municipals a les espanyoles")

axs[1].set_title("Resultats 2019")
axs[1].pie(list(dict_resultats2019.values()), labels = list(dict_resultats2019.keys()),colors=color2);
axs[0].set_title("Projecció 2023")
axs[0].pie(list(dict_resultats.values()), labels = list(dict_resultats.keys()),colors=color1);

# %%
fig, axs = plt.subplots(1,2,figsize=(10, 3))
#fig.suptitle("Projecció resultats municipals a les espanyoles")

axs[1].set_title("Resultats 2019")
axs[1].bar(list(dict_resultats2019.keys()),list(dict_resultats2019.values()), color=color2);
axs[0].set_title("Projecció 2023")
axs[0].bar(list(dict_resultats.keys()),list(dict_resultats.values()), color=color1);

# %% [markdown]
# <h2> Projecció abstenció partits independentistes 50%

# %% [markdown]
# <h3> Lleida

# %%
res,limit,esconsRepartitsLleida = repartimentEscons(incrementAbstencio(resultats_Lleida,dades_eleccions,"Lleida",0.5),esconsLleida,partits_Lleida)
dataLleida = pd.DataFrame(res, columns=dades_lleida["Vots"])
dataLleida.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# Augment abstenció quan els indepes perden el 50.0% dels vots: 15.88 %
# <style type="text/css">
# #T_26d88_row0_col0, #T_26d88_row0_col1, #T_26d88_row0_col2, #T_26d88_row1_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_26d88">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_26d88_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_26d88_level0_col1" class="col_heading level0 col1" >Junts</th>
#       <th id="T_26d88_level0_col2" class="col_heading level0 col2" >PSC</th>
#       <th id="T_26d88_level0_col3" class="col_heading level0 col3" >ARA PL</th>
#       <th id="T_26d88_level0_col4" class="col_heading level0 col4" >CUP</th>
#       <th id="T_26d88_level0_col5" class="col_heading level0 col5" >PP</th>
#       <th id="T_26d88_level0_col6" class="col_heading level0 col6" >CDA-PNA</th>
#       <th id="T_26d88_level0_col7" class="col_heading level0 col7" >AAE1PALLARSSOBIRA</th>
#       <th id="T_26d88_level0_col8" class="col_heading level0 col8" >EV</th>
#       <th id="T_26d88_level0_col9" class="col_heading level0 col9" >AGRUPACIÓ D'ELECTORS-PRIMER ALCOLETGE</th>
#       <th id="T_26d88_level0_col10" class="col_heading level0 col10" >APC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26d88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26d88_row0_col0" class="data row0 col0" >24050</td>
#       <td id="T_26d88_row0_col1" class="data row0 col1" >23761</td>
#       <td id="T_26d88_row0_col2" class="data row0 col2" >30950</td>
#       <td id="T_26d88_row0_col3" class="data row0 col3" >8457</td>
#       <td id="T_26d88_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_26d88_row0_col5" class="data row0 col5" >10444</td>
#       <td id="T_26d88_row0_col6" class="data row0 col6" >145</td>
#       <td id="T_26d88_row0_col7" class="data row0 col7" >321</td>
#       <td id="T_26d88_row0_col8" class="data row0 col8" >363</td>
#       <td id="T_26d88_row0_col9" class="data row0 col9" >847</td>
#       <td id="T_26d88_row0_col10" class="data row0 col10" >783</td>
#     </tr>
#     <tr>
#       <th id="T_26d88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26d88_row1_col0" class="data row1 col0" >12025</td>
#       <td id="T_26d88_row1_col1" class="data row1 col1" >11880</td>
#       <td id="T_26d88_row1_col2" class="data row1 col2" >15475</td>
#       <td id="T_26d88_row1_col3" class="data row1 col3" >4228</td>
#       <td id="T_26d88_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_26d88_row1_col5" class="data row1 col5" >5222</td>
#       <td id="T_26d88_row1_col6" class="data row1 col6" >72</td>
#       <td id="T_26d88_row1_col7" class="data row1 col7" >160</td>
#       <td id="T_26d88_row1_col8" class="data row1 col8" >182</td>
#       <td id="T_26d88_row1_col9" class="data row1 col9" >424</td>
#       <td id="T_26d88_row1_col10" class="data row1 col10" >392</td>
#     </tr>
#     <tr>
#       <th id="T_26d88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26d88_row2_col0" class="data row2 col0" >8016</td>
#       <td id="T_26d88_row2_col1" class="data row2 col1" >7920</td>
#       <td id="T_26d88_row2_col2" class="data row2 col2" >10317</td>
#       <td id="T_26d88_row2_col3" class="data row2 col3" >2819</td>
#       <td id="T_26d88_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_26d88_row2_col5" class="data row2 col5" >3481</td>
#       <td id="T_26d88_row2_col6" class="data row2 col6" >48</td>
#       <td id="T_26d88_row2_col7" class="data row2 col7" >107</td>
#       <td id="T_26d88_row2_col8" class="data row2 col8" >121</td>
#       <td id="T_26d88_row2_col9" class="data row2 col9" >282</td>
#       <td id="T_26d88_row2_col10" class="data row2 col10" >261</td>
#     </tr>
#     <tr>
#       <th id="T_26d88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26d88_row3_col0" class="data row3 col0" >6012</td>
#       <td id="T_26d88_row3_col1" class="data row3 col1" >5940</td>
#       <td id="T_26d88_row3_col2" class="data row3 col2" >7738</td>
#       <td id="T_26d88_row3_col3" class="data row3 col3" >2114</td>
#       <td id="T_26d88_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_26d88_row3_col5" class="data row3 col5" >2611</td>
#       <td id="T_26d88_row3_col6" class="data row3 col6" >36</td>
#       <td id="T_26d88_row3_col7" class="data row3 col7" >80</td>
#       <td id="T_26d88_row3_col8" class="data row3 col8" >91</td>
#       <td id="T_26d88_row3_col9" class="data row3 col9" >212</td>
#       <td id="T_26d88_row3_col10" class="data row3 col10" >196</td>
#     </tr>
#   </tbody>
# </table>

# %%
dict_resultatsLleida = {}
for i in partits:
    dict_resultatsLleida[i] = esconsRepartitsLleida.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsLleida.keys()),list(dict_resultatsLleida.values()), color=color1);

# %% [markdown]
# <h3> Barcelona

# %%
res,limit,esconsRepartitsBarcelona = repartimentEscons(incrementAbstencio(resultats_Barcelona,dades_eleccions,"Barcelona",0.5),esconsBarcelona,partits_Barcelona)
dataBarcelona = pd.DataFrame(res, columns=dades_barcelona["Vots"])
dataBarcelona.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# Augment abstenció quan els indepes perden el 50.0% dels vots: 9.62 %
# <style type="text/css">
# #T_6bafd_row0_col0, #T_6bafd_row0_col1, #T_6bafd_row0_col2, #T_6bafd_row0_col3, #T_6bafd_row0_col5, #T_6bafd_row0_col6, #T_6bafd_row1_col0, #T_6bafd_row1_col1, #T_6bafd_row1_col2, #T_6bafd_row1_col3, #T_6bafd_row1_col5, #T_6bafd_row1_col6, #T_6bafd_row2_col0, #T_6bafd_row2_col1, #T_6bafd_row2_col2, #T_6bafd_row2_col3, #T_6bafd_row2_col5, #T_6bafd_row3_col1, #T_6bafd_row3_col2, #T_6bafd_row3_col3, #T_6bafd_row3_col5, #T_6bafd_row4_col1, #T_6bafd_row4_col3, #T_6bafd_row4_col5, #T_6bafd_row5_col1, #T_6bafd_row6_col1, #T_6bafd_row7_col1, #T_6bafd_row8_col1, #T_6bafd_row9_col1, #T_6bafd_row10_col1, #T_6bafd_row11_col1, #T_6bafd_row12_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_6bafd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_6bafd_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_6bafd_level0_col1" class="col_heading level0 col1" >PSC</th>
#       <th id="T_6bafd_level0_col2" class="col_heading level0 col2" >Junts</th>
#       <th id="T_6bafd_level0_col3" class="col_heading level0 col3" >Comuns</th>
#       <th id="T_6bafd_level0_col4" class="col_heading level0 col4" >CUP</th>
#       <th id="T_6bafd_level0_col5" class="col_heading level0 col5" >PP</th>
#       <th id="T_6bafd_level0_col6" class="col_heading level0 col6" >VOX</th>
#       <th id="T_6bafd_level0_col7" class="col_heading level0 col7" >ARA PL</th>
#       <th id="T_6bafd_level0_col8" class="col_heading level0 col8" >AAE1OSONA</th>
#       <th id="T_6bafd_level0_col9" class="col_heading level0 col9" >TXT</th>
#       <th id="T_6bafd_level0_col10" class="col_heading level0 col10" >AM-LVDVDM</th>
#       <th id="T_6bafd_level0_col11" class="col_heading level0 col11" >POBLE UNIT</th>
#       <th id="T_6bafd_level0_col12" class="col_heading level0 col12" >MXGI</th>
#       <th id="T_6bafd_level0_col13" class="col_heading level0 col13" >FIC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bafd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bafd_row0_col0" class="data row0 col0" >166157</td>
#       <td id="T_6bafd_row0_col1" class="data row0 col1" >571901</td>
#       <td id="T_6bafd_row0_col2" class="data row0 col2" >178322</td>
#       <td id="T_6bafd_row0_col3" class="data row0 col3" >243065</td>
#       <td id="T_6bafd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6bafd_row0_col5" class="data row0 col5" >211593</td>
#       <td id="T_6bafd_row0_col6" class="data row0 col6" >120213</td>
#       <td id="T_6bafd_row0_col7" class="data row0 col7" >27384</td>
#       <td id="T_6bafd_row0_col8" class="data row0 col8" >3724</td>
#       <td id="T_6bafd_row0_col9" class="data row0 col9" >26732</td>
#       <td id="T_6bafd_row0_col10" class="data row0 col10" >2577</td>
#       <td id="T_6bafd_row0_col11" class="data row0 col11" >216</td>
#       <td id="T_6bafd_row0_col12" class="data row0 col12" >1862</td>
#       <td id="T_6bafd_row0_col13" class="data row0 col13" >1448</td>
#     </tr>
#     <tr>
#       <th id="T_6bafd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6bafd_row1_col0" class="data row1 col0" >83078</td>
#       <td id="T_6bafd_row1_col1" class="data row1 col1" >285950</td>
#       <td id="T_6bafd_row1_col2" class="data row1 col2" >89161</td>
#       <td id="T_6bafd_row1_col3" class="data row1 col3" >121532</td>
#       <td id="T_6bafd_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_6bafd_row1_col5" class="data row1 col5" >105796</td>
#       <td id="T_6bafd_row1_col6" class="data row1 col6" >60106</td>
#       <td id="T_6bafd_row1_col7" class="data row1 col7" >13692</td>
#       <td id="T_6bafd_row1_col8" class="data row1 col8" >1862</td>
#       <td id="T_6bafd_row1_col9" class="data row1 col9" >13366</td>
#       <td id="T_6bafd_row1_col10" class="data row1 col10" >1288</td>
#       <td id="T_6bafd_row1_col11" class="data row1 col11" >108</td>
#       <td id="T_6bafd_row1_col12" class="data row1 col12" >931</td>
#       <td id="T_6bafd_row1_col13" class="data row1 col13" >724</td>
#     </tr>
#     <tr>
#       <th id="T_6bafd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6bafd_row2_col0" class="data row2 col0" >55386</td>
#       <td id="T_6bafd_row2_col1" class="data row2 col1" >190634</td>
#       <td id="T_6bafd_row2_col2" class="data row2 col2" >59441</td>
#       <td id="T_6bafd_row2_col3" class="data row2 col3" >81022</td>
#       <td id="T_6bafd_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_6bafd_row2_col5" class="data row2 col5" >70531</td>
#       <td id="T_6bafd_row2_col6" class="data row2 col6" >40071</td>
#       <td id="T_6bafd_row2_col7" class="data row2 col7" >9128</td>
#       <td id="T_6bafd_row2_col8" class="data row2 col8" >1241</td>
#       <td id="T_6bafd_row2_col9" class="data row2 col9" >8911</td>
#       <td id="T_6bafd_row2_col10" class="data row2 col10" >859</td>
#       <td id="T_6bafd_row2_col11" class="data row2 col11" >72</td>
#       <td id="T_6bafd_row2_col12" class="data row2 col12" >621</td>
#       <td id="T_6bafd_row2_col13" class="data row2 col13" >483</td>
#     </tr>
#     <tr>
#       <th id="T_6bafd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6bafd_row3_col0" class="data row3 col0" >41539</td>
#       <td id="T_6bafd_row3_col1" class="data row3 col1" >142975</td>
#       <td id="T_6bafd_row3_col2" class="data row3 col2" >44580</td>
#       <td id="T_6bafd_row3_col3" class="data row3 col3" >60766</td>
#       <td id="T_6bafd_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_6bafd_row3_col5" class="data row3 col5" >52898</td>
#       <td id="T_6bafd_row3_col6" class="data row3 col6" >30053</td>
#       <td id="T_6bafd_row3_col7" class="data row3 col7" >6846</td>
#       <td id="T_6bafd_row3_col8" class="data row3 col8" >931</td>
#       <td id="T_6bafd_row3_col9" class="data row3 col9" >6683</td>
#       <td id="T_6bafd_row3_col10" class="data row3 col10" >644</td>
#       <td id="T_6bafd_row3_col11" class="data row3 col11" >54</td>
#       <td id="T_6bafd_row3_col12" class="data row3 col12" >466</td>
#       <td id="T_6bafd_row3_col13" class="data row3 col13" >362</td>
#     </tr>
#     <tr>
#       <th id="T_6bafd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6bafd_row4_col0" class="data row4 col0" >33231</td>
#       <td id="T_6bafd_row4_col1" class="data row4 col1" >114380</td>
#       <td id="T_6bafd_row4_col2" class="data row4 col2" >35664</td>
#       <td id="T_6bafd_row4_col3" class="data row4 col3" >48613</td>
#       <td id="T_6bafd_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_6bafd_row4_col5" class="data row4 col5" >42319</td>
#       <td id="T_6bafd_row4_col6" class="data row4 col6" >24043</td>
#       <td id="T_6bafd_row4_col7" class="data row4 col7" >5477</td>
#       <td id="T_6bafd_row4_col8" class="data row4 col8" >745</td>
#       <td id="T_6bafd_row4_col9" class="data row4 col9" >5346</td>
#       <td id="T_6bafd_row4_col10" class="data row4 col10" >515</td>
#       <td id="T_6bafd_row4_col11" class="data row4 col11" >43</td>
#       <td id="T_6bafd_row4_col12" class="data row4 col12" >372</td>
#       <td id="T_6bafd_row4_col13" class="data row4 col13" >290</td>
#     </tr>
#     <tr>
#       <th id="T_6bafd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6bafd_row5_col0" class="data row5 col0" >27693</td>
#       <td id="T_6bafd_row5_col1" class="data row5 col1" >95317</td>
#       <td id="T_6bafd_row5_col2" class="data row5 col2" >29720</td>
#       <td id="T_6bafd_row5_col3" class="data row5 col3" >40511</td>
#       <td id="T_6bafd_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_6bafd_row5_col5" class="data row5 col5" >35266</td>
#       <td id="T_6bafd_row5_col6" class="data row5 col6" >20036</td>
#       <td id="T_6bafd_row5_col7" class="data row5 col7" >4564</td>
#       <td id="T_6bafd_row5_col8" class="data row5 col8" >621</td>
#       <td id="T_6bafd_row5_col9" class="data row5 col9" >4455</td>
#       <td id="T_6bafd_row5_col10" class="data row5 col10" >430</td>
#       <td id="T_6bafd_row5_co

# %%
dict_resultatsBarcelona = {}
for i in partits:
    dict_resultatsBarcelona[i] = esconsRepartitsBarcelona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsBarcelona.keys()),list(dict_resultatsBarcelona.values()), color=color1);

# %% [markdown]
# <h3> Girona

# %%
res,limit,esconsRepartitsGirona = repartimentEscons(incrementAbstencio(resultats_Girona,dades_eleccions,"Girona",0.50),esconsGirona,partits_Girona)
dataGirona = pd.DataFrame(res, columns=dades_girona["Vots"])
dataGirona.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# Augment abstenció quan els indepes perden el 50.0% dels vots: 15.74 %
# <style type="text/css">
# #T_3ecc6_row0_col0, #T_3ecc6_row0_col1, #T_3ecc6_row0_col2, #T_3ecc6_row1_col0, #T_3ecc6_row1_col1, #T_3ecc6_row1_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_3ecc6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_3ecc6_level0_col0" class="col_heading level0 col0" >Junts</th>
#       <th id="T_3ecc6_level0_col1" class="col_heading level0 col1" >ERC</th>
#       <th id="T_3ecc6_level0_col2" class="col_heading level0 col2" >PSC</th>
#       <th id="T_3ecc6_level0_col3" class="col_heading level0 col3" >CUP</th>
#       <th id="T_3ecc6_level0_col4" class="col_heading level0 col4" >TE</th>
#       <th id="T_3ecc6_level0_col5" class="col_heading level0 col5" >IDSELVA</th>
#       <th id="T_3ecc6_level0_col6" class="col_heading level0 col6" >IDC</th>
#       <th id="T_3ecc6_level0_col7" class="col_heading level0 col7" >VOX</th>
#       <th id="T_3ecc6_level0_col8" class="col_heading level0 col8" >Comuns</th>
#       <th id="T_3ecc6_level0_col9" class="col_heading level0 col9" >ARA PL</th>
#       <th id="T_3ecc6_level0_col10" class="col_heading level0 col10" >PP</th>
#       <th id="T_3ecc6_level0_col11" class="col_heading level0 col11" >SOMMESCAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ecc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ecc6_row0_col0" class="data row0 col0" >40244</td>
#       <td id="T_3ecc6_row0_col1" class="data row0 col1" >32329</td>
#       <td id="T_3ecc6_row0_col2" class="data row0 col2" >40045</td>
#       <td id="T_3ecc6_row0_col3" class="data row0 col3" >11618</td>
#       <td id="T_3ecc6_row0_col4" class="data row0 col4" >12787</td>
#       <td id="T_3ecc6_row0_col5" class="data row0 col5" >8071</td>
#       <td id="T_3ecc6_row0_col6" class="data row0 col6" >2221</td>
#       <td id="T_3ecc6_row0_col7" class="data row0 col7" >8608</td>
#       <td id="T_3ecc6_row0_col8" class="data row0 col8" >7223</td>
#       <td id="T_3ecc6_row0_col9" class="data row0 col9" >6546</td>
#       <td id="T_3ecc6_row0_col10" class="data row0 col10" >7186</td>
#       <td id="T_3ecc6_row0_col11" class="data row0 col11" >1624</td>
#     </tr>
#     <tr>
#       <th id="T_3ecc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3
_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ecc6_row4_col0" class="data row4 col0" >8049</td>
#       <td id="T_3ecc6_row4_col1" class="data row4 col1" >6466</td>
#       <td id="T_3ecc6_row4_col2" class="data row4 col2" >8009</td>
#       <td id="T_3ecc6_row4_col3" class="data row4 col3" >2324</td>
#       <td id="T_3ecc6_row4_col4" class="data row4 col4" >2557</td>
#       <td id="T_3ecc6_row4_col5" class="data row4 col5" >1614</td>
#       <td id="T_3ecc6_row4_col6" class="data row4 col6" >444</td>
#       <td id="T_3ecc6_row4_col7" class="data row4 col7" >1722</td>
#       <td id="T_3ecc6_row4_col8" class="data row4 col8" >1445</td>
#       <td id="T_3ecc6_row4_col9" class="data row4 col9" >1309</td>
#       <td id="T_3ecc6_row4_col10" class="data row4 col10" >1437</td>
#       <td id="T_3ecc6_row4_col11" class="data row4 col11" >325</td>
#     </tr>
#     <tr>
#       <th id="T_3ecc6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ecc6_row5_col0" class="data row5 col0" >6707</td>
#       <td id="T_3ecc6_row5_col1" class="data row5 col1" >5388</td>
#       <td id="T_3ecc6_row5_col2" class="data row5 col2" >6674</td>
#       <td id="T_3ecc6_row5_col3" class="data row5 col3" >1936</td>
#       <td id="T_3ecc6_row5_col4" class="data row5 col4" >2131</td>
#       <td id="T_3ecc6_row5_col5" class="data row5 col5" >1345</td>
#       <td id="T_3ecc6_row5_col6" class="data row5 col6" >370</td>
#       <td id="T_3ecc6_row5_col7" class="data row5 col7" >1435</td>
#       <td id="T_3ecc6_row5_col8" class="data row5 col8" >1204</td>
#       <td id="T_3ecc6_row5_col9" class="data row5 col9" >1091</td>
#       <td id="T_3ecc6_row5_col10" class="data row5 col10" >1198</td>
#       <td id="T_3ecc6_row5_col11" class="data row5 col11" >271</td>
#     </tr>
#   </tbody>
# </table>

# %%
dict_resultatsGirona = {}
for i in partits:
    dict_resultatsGirona[i] = esconsRepartitsGirona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultatsGirona.keys()),list(dict_resultatsGirona.values()), color=color1);

# %% [markdown]
# <h3> Tarragona

# %%
res,limit,esconsRepartitsTarragona = repartimentEscons(incrementAbstencio(resultats_Tarragona,dades_eleccions,"Tarragona",0.50),esconsGirona,partits_Tarragona)
dataTarragona = pd.DataFrame(res, columns=dades_tarragona["Vots"])
dataTarragona.style.applymap(lambda x: 'background-color : green' if x>=limit else '')
# Out:
# Augment abstenció quan els indepes perden el 50.0% dels vots: 13.06 %
# <style type="text/css">
# #T_57aaf_row0_col0, #T_57aaf_row0_col1, #T_57aaf_row0_col2, #T_57aaf_row1_col0, #T_57aaf_row1_col2, #T_57aaf_row2_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_57aaf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vots</th>
#       <th id="T_57aaf_level0_col0" class="col_heading level0 col0" >ERC</th>
#       <th id="T_57aaf_level0_col1" class="col_heading level0 col1" >Junts</th>
#       <th id="T_57aaf_level0_col2" class="col_heading level0 col2" >PSC</th>
#       <th id="T_57aaf_level0_col3" class="col_heading level0 col3" >ARA PL</th>
#       <th id="T_57aaf_level0_col4" class="col_heading level0 col4" >F.I.C.</th>
#       <th id="T_57aaf_level0_col5" class="col_heading level0 col5" >Comuns</th>
#       <th id="T_57aaf_level0_col6" class="col_heading level0 col6" >CUP</th>
#       <th id="T_57aaf_level0_col7" class="col_heading level0 col7" >PP</th>
#       <th id="T_57aaf_level0_col8" class="col_heading level0 col8" >VOX</th>
#       <th id="T_57aaf_level0_col9" class="col_heading level0 col9" >APCANVI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57aaf_row4_col0" class="data row4 col0" >7476</td>
#       <td id="T_57aaf_row4_col1" class="data row4 col1" >6744</td>
#       <td id="T_57aaf_row4_col2" class="data row4 col2" >14011</td>
#       <td id="T_57aaf_row4_col3" class="data row4 col3" >2611</td>
#       <td id="T_57aaf_row4_col4" class="data row4 col4" >791</td>
#       <td id="T_57aaf_row4_col5" class="data row4 col5" >2493</td>
#       <td id="T_57aaf_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_57aaf_row4_col7" class="data row4 col7" >3578</td>
#       <td id="T_57aaf_row4_col8" class="data row4 col8" >3359</td>
#       <td id="T_57aaf_row4_col9" class="data row4 col9" >328</td>
#     </tr>
#     <tr>
#       <th id="T_57aaf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57aaf_row5_col0" class="data row5 col0" >6230</td>
#       <td id="T_57aaf_row5_col1" class="data row5 col1" >5620</td>
#       <td id="T_57aaf_row5_col2" class="data row5 col2" >11676</td>
#       <td id="T_57aaf_row5_col3" class="data row5 col3" >2176</td>
#       <td id="T_57aaf_row5_col4" class="data row5 col4" >659</td>
#       <td id="T_57aaf_row5_col5" class="data row5 col5" >2078</td>
#       <td id="T_57aaf_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_57aaf_row5_col7" class="data row5 col7" >2982</td>
#       <td id="T_57aaf_row5_col8" class="data row5 col8" >2799</td>
#       <td id="T_57aaf_row5_col9" class="data row5 col9" >273</td>
#     </tr>
#   </tbody>
# </table>

# %%
dict_resultatsTarragona = {}
for i in partits:
    dict_resultatsTarragona[i] = esconsRepartitsTarragona.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Ciudadanos"]

plt.bar(list(dict_resultatsTarragona.keys()),list(dict_resultatsTarragona.values()), color=color1);

# %% [markdown]
# <h2> Resultats generals tenint en compte abstenció del 50%, comparat amb resultats de 2019

# %%
esconsCatalunya = esconsRepartitsBarcelona + esconsRepartitsGirona + esconsRepartitsLleida + esconsRepartitsTarragona

dict_resultats = {}
for i in partits:
    dict_resultats[i] = esconsCatalunya.count(i)
#["Erc","PSC","Junts","PP","Comuns","CUP","VOX","Cs"]

plt.bar(list(dict_resultats.keys()),list(dict_resultats.values()), color=color1);

# %%
dict_resultats = {}
for i in partits:
    dict_resultats[i] = esconsCatalunya.count(i)
  
plt.pie(list(dict_resultats.values()), labels = list(dict_resultats.keys()),colors=color2);

# %%
fig, axs = plt.subplots(1,2,figsize=(10, 3))
#fig.suptitle("Projecció resultats municipals a les espanyoles")

axs[1].set_title("Resultats 2019")
axs[1].bar(list(dict_resultats2019.keys()),list(dict_resultats2019.values()), color=color2);
axs[0].set_title("Projecció 2023 amb 50% abstenció independentista")
axs[0].bar(list(dict_resultats.keys()),list(dict_resultats.values()), color=color1);

# %%
from ipywidgets import interact

@interact
def plot_polynom(a=[0, 1, 2, 3], b=2, c = 100):
    x = np.arange(-10, 10, 0.1)
    y = a*x**3+ b*x**2 + c    

    plt.plot(x,y); 
    plt.xlim(xmin=-10, xmax=10);
    plt.ylim(ymin=-100, ymax=1000)
# Out:
# interactive(children=(Dropdown(description='a', options=(0, 1, 2, 3), value=0), IntSlider(value=2, description…
